# %%
import pandas as pd

# %%
df = pd.read_csv('challenger_gameData.csv')
df
# Out:
#         Unnamed: 0  win      gameId  gameDuration  kills  deaths  assists  \
# 0                0    1  6145654174          1682      4       3       10
# 1                1    1  6145654174          1682      6       5       14
# 2                2    1  6145654174          1682     19       5        8
# 3                3    1  6145654174          1682     10      10       11
# 4                4    1  6145654174          1682      3       4       26
# ...            ...  ...         ...           ...    ...     ...      ...
# 141315      141315    0  6139731589          1213      2       5        7
# 141316      141316    0  6139731589          1213      7       5        6
# 141317      141317    0  6139731589          1213      9       9        0
# 141318      141318    0  6139731589          1213      2       5        9
# 141319      141319    0  6139731589          1213      2       7        7
#
#         goldEarned  champLevel  dragonKills  ...  takenDamage  teamId  \
# ...

# %%
d = df[df['gameDuration']<500].index

# %%
df.drop(d,inplace=True)

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'win', 'gameId', 'gameDuration', 'kills', 'deaths',
#        'assists', 'goldEarned', 'champLevel', 'dragonKills', 'baronKills',
#        'inhibitorKills', 'wardsKilled', 'wardsPlaced', 'visionScore',
#        'CS', 'totalHeal', 'takeDamage', 'takenDamage', 'teamId',
#        'position', 'firstBloodKill', 'firstRiftHerald', 'firstDragon',
#        'firstTowerKill', 'firstBaron', 'firstInhibitor',
#        'elderDragonTime'], dtype=object)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df = df[['gameId','win','firstBloodKill','firstTowerKill','firstDragon','firstRiftHerald','firstBaron','firstInhibitor','elderDragonTime','teamId']]

# %%
# df.groupby('gameId')['win','firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor','firstRiftHerald','elderDragonTime','teamId'].sum()

# %%
def zero(x):
    if x == 0: return 0
    else : return 1

# %%
import numpy as np

# %%
df['elderDragonTime'] = df['elderDragonTime'].apply(zero)
# Out:
# C:\Users\tjoeun-jr-902-12\AppData\Local\Temp\ipykernel_8412\1268933238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['elderDragonTime'] = df['elderDragonTime'].apply(zero)

# %%
df['elderDragonTime'].value_counts()
# Out:
# 0    140390
# 1       450
# Name: elderDragonTime, dtype: int64

# %%
df.groupby(['win']).sum()[['firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor','elderDragonTime']]
# Out:
#      firstTowerKill  firstBloodKill  firstBaron  firstDragon  firstInhibitor  \
# win
# 0             19350           28260        5510        17870            5185
# 1             51000           42155       27315        37615           43840
#
#      elderDragonTime
# win
# 0                110
# 1                340

# %%
splitTeam = df.groupby(['win'])['firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor','elderDragonTime'].sum()
# Out:
# C:\Users\tjoeun-jr-902-12\AppData\Local\Temp\ipykernel_8412\3456802057.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   splitTeam = df.groupby(['win'])['firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor','elderDragonTime'].sum()

# %%
splitTeam[['firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor']] = (splitTeam[['firstTowerKill','firstBloodKill','firstBaron','firstDragon','firstInhibitor']]/5).astype(int)

# %%
splitTeam
# Out:
#      firstTowerKill  firstBloodKill  firstBaron  firstDragon  firstInhibitor  \
# win
# 0              3870            5652        1102         3574            1037
# 1             10200            8431        5463         7523            8768
#
#      elderDragonTime
# win
# 0                110
# 1                340

# %%
splitTeam.corr()
# Out:
#                  firstTowerKill  firstBloodKill  firstBaron  firstDragon  \
# firstTowerKill              1.0             1.0         1.0          1.0
# firstBloodKill              1.0             1.0         1.0          1.0
# firstBaron                  1.0             1.0         1.0          1.0
# firstDragon                 1.0             1.0         1.0          1.0
# firstInhibitor              1.0             1.0         1.0          1.0
# elderDragonTime             1.0             1.0         1.0          1.0
#
#                  firstInhibitor  elderDragonTime
# firstTowerKill              1.0              1.0
# firstBloodKill              1.0              1.0
# firstBaron                  1.0              1.0
# firstDragon                 1.0              1.0
# firstInhibitor              1.0              1.0
# elderDragonTime             1.0              1.0
